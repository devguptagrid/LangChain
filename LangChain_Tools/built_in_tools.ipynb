# %%
# %pip install langchain langchain-core langchain-community pydantic duckduckgo-search ddgs langchain-experimental
# Out:
# Requirement already satisfied: langchain in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (1.2.15)
# Requirement already satisfied: langchain-core in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (1.2.26)
# Requirement already satisfied: langchain-community in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: pydantic in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (2.12.5)
# Requirement already satisfied: duckduckgo-search in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (8.1.1)
# Requirement already satisfied: ddgs in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (9.14.1)
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.4.1-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.1/210.1 kB 4.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain) (1.1.6)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-core) (0.7.25)
# Requirement already satisfied: packaging>=23.2.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-core) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-community) (2.33.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: click>=8.1.8 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from duckduckgo-search) (8.3.2)
# Requirement already satisfied: primp>=0.15.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from duckduckgo-search) (1.2.3)
# Requirement already satisfied: lxml>=5.3.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from duckduckgo-search) (6.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.2.25)
# Requirement already satisfied: anyio in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Installing collected packages: langchain-experimental
# Successfully installed langchain-experimental-0.4.1
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Built-in Tool - DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool=DuckDuckGoSearchRun()

results=search_tool.invoke('ipl news')

print(results)
# Out:
# Stay updated with today's cricket news, live scores, and expert analysis. Covering the IPL 2026, Test matches, and domestic leagues worldwide. Get breaking stories, player interviews, and match ... Stay informed with all important IPL 2026 announcements, including player updates and squad changes. Get the latest news on IPLT20. News Get the latest cricket news, match updates, player insights & breaking stories on IPL.com. Stay ahead with real-time cricket headlines, live scores, and in-depth analysis from top leagues worldwide. IPL 2026 🏏 : Get live IPL 2026 coverage with match schedules, points tables, fixtures, match results, and the latest IPL news. Follow defending champions RCB and all 10 teams through the 84 ... Cricket IPL Score Today: Get live scores, news, schedules, highlights, commentary, points table, videos, stats, Indian Premier League match today and more updates for IPL 2026 only on CricTracker.

# %% [markdown]
# ## Built-in Tool - Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool= ShellTool()

results= shell_tool.invoke('who am i ')

print(results)
# Out:
# Executing command:
#  who am i
# devgupta                      Apr 22 10:22
# /Users/devgupta/Desktop/LangChain/venv/lib/python3.11/site-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
